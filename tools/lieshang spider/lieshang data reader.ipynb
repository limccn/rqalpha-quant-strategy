# %%
# !find ./download -name "*.json"
# Out:
# ./download/R058767.json
# ./download/R058352.json
# ./download/R091119.json
# ./download/R080334.json
# ./download/R092367.json
# ./download/R098664.json
# ./download/R046064.json
# ./download/R049826.json
# ./download/R016089.json
# ./download/R020888.json
# ./download/R048560.json
# ./download/R037807.json
# ./download/R027043.json
# ./download/R010888.json
# ./download/R023113.json
# ./download/R032582.json
# ./download/R035105.json
# ./download/R036483.json
# ./download/R063560.json
# ./download/R029228.json
# ./download/R076469.json
# ./download/R013717.json
# ./download/R065642.json
# ./download/R015070.json
# ./download/R069918.json
# ./download/R066808.json
# ./download/R065181.json
# ./download/R028090.json
# ./download/R012450.json
# ./download/R037599.json
# ./download/R032178.json
# ./download/R090708.json
# ./download/R076072.json
# ./download/R086238.json
# ./download/R044939.json
# ./download/R080547.json
# ./download/R036793.json
# ./download/R064183.json
# ...

# %%
content = ''
save_path = './download/R064896.json' 
fp = None
try:
    fp = open(save_path, 'r') 
    content = fp.read() 
except:
    print('read resume failed')
finally:
    if (fp <> None):
        fp.close()
        fp = None

print content.decode('unicode_escape')
# Out:
# {"info":{"id":"64896","update_time":"1417190400","name":"王晶","sex":"2","marriage":"0","height":null,"birth_year":"1991","city":"铁岭","residence":null,"nationality":null,"id_card":null,"phone":"18241002760","email":"wangjing218238@126.com","qq":null,"address":null,"postcode":null,"first_degree":null,"degree":"1","major":"酒店管理","school":"沈阳广播电视大学","work_begin":null,"industry":"酒店\/旅游","last_company":"沈阳天丰国际酒店","last_position":"大堂经理","current_salary":"3-4万人民币","base_front":null,"bonus":null,"allowance":null,"target_industry":"酒店\/旅游，服装\/纺织\/皮革，公关\/市场推广\/会展","target_salary":null,"target_city":"沈阳","target_position":"销售人员，大堂经理","self_str":"本人通过以往的工作经验培养出较强的服务意思与灵活处理突发事件的能力，拥有良好的心态抗压能力强，可以很快的适应工作环境，本人拥有较强的责任心和团队意识。熟悉Word／Excel    中文打字80／分钟","xiejun_id":"63743","md5":"6f6aa99ce30090ddbe78fc8d3ed18b85","resume":"应聘职位：影院助理经理（铁岭）应聘公司：大地影院发展有限公司投递时间：2014-11-19更新时间：2014-11-29简历关键字：酒店 销售 适应能力强 口才好 服务意识好王晶匹配度：56% 3-4年工作经验 |女 | 23岁（1991年3月8日） | 未婚 | 165cm| 团员(ID:56640191)居住地：铁岭电 话：18241002760（手机）E-m
# ...
